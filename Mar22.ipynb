# %%
#1
import numpy as np
import pandas as pd

# Example data
df = pd.DataFrame({'studying_time' : [10, 12, 8, 15, 9],
                  'exam_scores' : [75, 80, 65, 90, 70]})
df.corr(method = 'pearson')
# Out:
#                studying_time  exam_scores
# studying_time       1.000000     0.992955
# exam_scores         0.992955     1.000000

# %%
'''
The Corelation between study time and exam score is perfect positve linear relation
'''

# %%
#2
df1 = pd.DataFrame({'sleep_hours' : [7, 6, 8, 6, 5],
'job_satisfaction' : [8, 7, 9, 6, 5]
})
df1.corr(method = 'pearson')
# Out:
#                   sleep_hours  job_satisfaction
# sleep_hours          1.000000          0.970725
# job_satisfaction     0.970725          1.000000

# %%
'''
The Corelation between sleep hours and job satisfaction is positve monotonic relation.
'''

# %%
#3
import scipy.stats as stats

exercise_hours = [4, 3, 5, 2, 4, 3, 6, 2, 3, 2, 5, 4, 3, 6, 2, 3, 5, 4, 3, 6,
                  2, 3, 5, 4, 3, 6, 2, 3, 5, 4, 3, 6, 2, 3, 5, 4, 3, 6, 2, 3,
                  5, 4, 3, 6, 2, 3, 5, 4, 3, 6]
bmi = [22.3, 24.1, 25.8, 28.4, 21.7, 23.2, 26.1, 27.9, 29.8, 30.2, 23.7, 24.6,
       26.5, 28.3, 30.5, 23.1, 24.3, 25.6, 28.9, 31.2, 23.4, 24.9, 26.4, 29.1,
       32.0, 23.8, 25.1, 26.8, 29.5, 33.1, 24.0, 25.4, 27.2, 30.0, 33.8, 24.2,
       25.7, 27.6, 30.7, 34.5, 24.4, 26.0, 27.9, 31.4, 35.2, 24.5, 26.2, 28.2,
       31.9, 35.8]

pearson_corr, _ = stats.pearsonr(exercise_hours, bmi)
spearman_corr, _ = stats.spearmanr(exercise_hours, bmi)

print("Pearson correlation coefficient:", pearson_corr)
print("Spearman's rank correlation coefficient:", spearman_corr)
# Out:
# Pearson correlation coefficient: -0.028531216982242882
# Spearman's rank correlation coefficient: -0.0711036669374977

# %%
#4
tv_hours = [3, 4, 2, 5, 4, 3, 6, 2, 3, 2, 5, 4, 3, 6, 2, 3, 5, 4, 3, 6,
            2, 3, 5, 4, 3, 6, 2, 3, 5, 4, 3, 6, 2, 3, 5, 4, 3, 6, 2, 3,
            5, 4, 3, 6, 2, 3, 5, 4, 3, 6]
physical_activity = [2, 3, 2, 4, 3, 2, 4, 2, 3, 2, 4, 3, 2, 4, 2, 3, 4, 3, 2, 4,
                     2, 3, 4, 3, 2, 4, 2, 3, 4, 3, 2, 4, 2, 3, 4, 3, 2, 4, 2, 3,
                     4, 3, 2, 4, 2, 3, 4, 3, 2, 4]

pearson,_ = stats.pearsonr(tv_hours,physical_activity)
print('The Pearson correlation coefficient between number of hours individuals spend watching television and physical activity :',pearson)
# Out:
# The Pearson correlation coefficient between number of hours individuals spend watching television and physical activity : 0.915801478492138

# %% [markdown]
# #5
# ![image.png](attachment:dbdc9400-dced-4a64-9d36-3dfb78d83304.png)
# Question is incomplete

# %%
#6
sales_calls_per_day = [10, 8, 12, 7, 9, 11, 10, 8, 12, 7, 9, 11, 10, 8, 12, 7, 9, 11, 10, 8,
                       12, 7, 9, 11, 10, 8, 12, 7, 9, 11]
sales_per_week = [50, 40, 60, 35, 45, 55, 50, 40, 60, 35, 45, 55, 50, 40, 60, 35, 45, 55,
                  50, 40, 60, 35, 45, 55, 50, 40, 60, 35, 45, 55]
pear_corr,_ = stats.pearsonr(sales_calls_per_day,sales_per_week)
pear_corr
# Out:
# 0.9999999999999999
