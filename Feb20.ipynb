# %%
#1
'''
GET - GET is used retrieve data from server.The data is sent in the URL as query,visible in address bar.
POST - POST is used to submit data to the server.The data is sent in the request body and not visible in address bar.
'''

# %%
#2
'''
The request module is used to access data sent in HTML forms through the POST or GET methods.
'''

# %%
#3
'''
The redirect() function is a method in Flask that is used to redirect the user to a different URL.It is commonly used
in web applications to redirect the user to a new page after they have completed a certain action or to redirect them
to the login page if they are not authenticated.
'''

# %%
#4
'''
Templates in Flask are files that are used to generate dynamic HTML content for web pages.
The render_template() function is used in Flask to render the HTML content of a template file. 
'''

# %%
#5
from flask import Flask, jsonify

app = Flask(__name__)

@app.route('/hello')
def hello():
    return jsonify({'message': 'Hello, World!'})

if __name__ == '__main__':
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.18.0.24:5000
# Press CTRL+C to quit
# 172.18.0.2 - - [03/Mar/2023 16:26:34] "GET / HTTP/1.1" 404 -
# 172.18.0.2 - - [03/Mar/2023 16:27:09] "GET / HTTP/1.1" 404 -
# 172.18.0.2 - - [03/Mar/2023 16:27:16] "GET / HTTP/1.1" 404 -
# 172.18.0.2 - - [03/Mar/2023 16:27:38] "GET /hello HTTP/1.1" 200 -

# %% [markdown]
# ![image.png](attachment:f13eebf1-cb82-4b80-9142-7d047ea43a30.png)
